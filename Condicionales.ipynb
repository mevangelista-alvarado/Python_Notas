# %% [markdown]
# <a href="https://colab.research.google.com/github/mevangelista-alvarado/Python_Notas/blob/master/Condicionales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2026-09-03 at 7.59.23 p.m..png](data:image/png;base64,...)

# %% [markdown]
# **Actualizado:** Septiembre 2026

# %% [markdown]
# # **Estructuras de control**

# %% [markdown]
# Las estructuras de control, denominadas también sentencias de control, permiten tomar decisiones y realizar un proceso repetidas veces. Son el conjunto de reglas que permiten controlar el flujo de ejecución de las instrucciones de un algoritmo o de un programa.
#
# La mayoría de los lenguajes de programación actuales soportan o utilizan las mismas estructuras de control o, al menos, son muy parecidas.

# %% [markdown]
# Los condicionales `if`, `elif`, `else` te permiten controlar el rumbo de la ejecución de un programa.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Explicación:
#
# 1. **Condicional `if`**:
# Se usa para ejecutar un bloque de código solo si una condición es verdadera.

# %%
edad = input("Tu edad es: ")
edad = int(edad)
# Out:
# Tu edad es: 27

# %%
if edad < 18:
    print("Eres menor de edad.")

# %% [markdown]
# 2. **Condicional `elif`**:
#    Significa "else if". Se usa para verificar múltiples condiciones. Solo se ejecuta si la condición anterior en el bloque `if` es falsa.

# %%
if edad < 18:
    print("Eres menor de edad.")
elif edad >= 18 and edad < 65:
      print("Tienes edad para votar.")
# Out:
# Tienes edad para votar.

# %% [markdown]
# 3. **Condicional `else`**:
# Se usa como un bloque final que se ejecuta si todas las condiciones anteriores son falsas.

# %%
if edad < 18:
      print("Eres menor de edad.")
elif edad >= 18 and edad < 65:
      print("Tienes edad para votar.")
else:
      print("Eres un adulto mayor.")
# Out:
# Tienes edad para votar.

# %% [markdown]
# Observación:
#
# Cuando necesitamos comprobar más de una condicion utilizamos `elif` tantas veces como sea necesario. También, mediante un `else` podemos destinar la ejecucicon de instrucciones si no se satisface ninguna condicion impuesta.

# %% [markdown]
# Otro ejemplo del uso del `if-else`, utilizando la función `input`

# %%
x = int(input("Introduce un numero entero: "))
if x < 0:
  x = 0
  print('Si es negativo lo cambio a cero')
elif x == 0:
  print('Cero')
elif x == 1:
  print('Uno')
else:
  print('Mayor a 1')
# Out:
# Introduce un numero entero: 7
# Mayor a 1

# %% [markdown]
# **Ejercicio**
#
# Recordando lo aprendido en la primer semana del curso realice un programa que realice lo siguiente:
#
# - Pida la calificaciones de un alumno y calcule su promedio.
# - Si la calificación es 90 o más, imprime "Obtuviste una A".
# - Si está entre 80 y 89, imprime "Obtuviste una B", y así sucesivamente.
# - Si ninguna de las condiciones anteriores es verdadera, imprime "Obtuviste una F".

# %%
#Resuelva el ejercicio

# %% [markdown]
# **Ejercicio 2**
#
# Ahora realice un programa que realice lo siguiente:
#
# 1. Si el usuario ingresa un número menor a 0, el programa mostrará: "La temperatura está por debajo del punto de congelación."
#
# 2. Si el usuario ingresa un número entre 1 y 15, el programa mostrará: "La temperatura es fría."
#
# 3. Si el usuario ingresa un número entre 16 y 25, el programa mostrará: "La temperatura es templada."
#
# 4. Si el usuario ingresa un número entre 26 y 35, el programa mostrará: "La temperatura es cálida."

# %%
#Resuelva el ejercicio
