# %% [markdown]
# <a href="https://colab.research.google.com/github/mevangelista-alvarado/Python_Notas/blob/master/Estructuras_de_Control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![urc_logo_ext.png](data:image/png;base64,...)

# %% [markdown]
# **Actualizado:** Septiembre de 2023
#
# **Autor:** Miguel Evangelista ([@mevagelista-alvarado](https://github.com/mevangelista-alvarado))

# %% [markdown]
# ## Estructuras de Control

# %% [markdown]
# Las __estructuras de control__, denominadas también sentencias de control, permiten tomar decisiones y realizar un proceso repetidas veces. Son el conjunto de reglas que permiten controlar el flujo de ejecución de las instrucciones de un algoritmo o de un programa.
#
# La mayoría de los lenguajes de programación actuales soportan o utilizan las mismas estructuras de control o, al menos, son muy parecidas.

# %% [markdown]
# ### Condicional ( If / elif / else )

# %% [markdown]
# El ciclo de decisión `if-else` permite controlar el rumbo de la ejecución de un programa.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Podemos condicionar la ejecución de ciertas instrucciones __sí__ cumplem cierta condicón dejando una espacio al comienzo de la línea (_indentanción_).

# %%
a = 1111
if a>10:
    print('Hola mundo')

# %% [markdown]
# Cuando necesitamos comprobar más de una condicion utilizamos `elif` tantas veces como sea necesario. También, mediante un `else` podemos destinar la ejecucicon de instrucciones si no se satisface ninguna condicion impuesta.
#
# __Ejercicio__: Completa el siguiente código.

# %%
a=  # Escribe un valor numerico para a
if a < 3:
    print('menor a tres')
elif a > 3:
    print('mayor a tres')
else:
    print('no es numero')

# %% [markdown]
# Otro ejemplo del uso del `if-else`, utilizando la función `input`

# %%
x = int(input("Introduce un numero entero: "))
if x < 0:
  x = 0
  print('Si es negativo lo cambio a cero')
elif x == 0:
  print('Cero')
elif x == 1:
  print('Uno')
else:
  print('Mayor a 1')

# %% [markdown]
# ### Ciclo `While`

# %% [markdown]
# Con el ciclo while podemos ejecutar un conjunto de declaraciones siempre que una condición sea verdadera.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Permite ejecutar un bloque de instrucciones ___mientras___ se cumpla una condición. Las instrucciones que deseamos repetir deben estar identadas.

# %%
contador = 1
while contador < 5:
    print(contador)
    contador = contador + 1

# %% [markdown]
# Podemos realizar _asignamiento multiple_. En Python, cualquier valor entero no cero es _verdadero_, mientras que _cero_ es _falso_.
#
# La condición del ciclo `while` también puede ser una variable de tipo `string` o una lista de valores.
#
# En general, cualquier sucesión de valores con una longitud no cero es _verdadero_, mientras que sucesiones de longitud cero  son _falsas_.

# %% [markdown]
# Ejemplo de la serie Fibonacci.

# %% [markdown]
# La sucesión comienza con los números $0$ y $1$,​ a partir de estos, cada término es la suma de los dos anteriores.

# %%
a, b = 0, 1
while a < 10:
  print(a)
  a , b = b , a + b

# %% [markdown]
# La palabra `end` puede usarse para evitar un salto de línea `(\n)` después de cada operación o para terminar el código con un caracter diferente:

# %%
a, b = 0, 1
while a < 1000:
  print(a, end = ', ')
  a , b = b , a+b

# %% [markdown]
# ### Ciclo `For`

# %% [markdown]
# Un ciclo for se usa para iterar sobre una estructura finita de elementos.

# %% [markdown]
# Esta instrucción recorre los elementos en una lista, por cada uno de ellos, repite un bloque de instrucciones.

# %%
lista=['a','b','c']
for elemento in lista:
    print(elemento)

# %% [markdown]
# ### La función `range( )`

# %% [markdown]
# Si necesitar iterar sobre una sucesión de números, podemos usar la función `range()`.

# %%
for i in range(5):
  print(i)

# %% [markdown]
# El número final dado nunca es parte de la sucesión generada, pero `range(5)` genera 5 valores, en este ejemplo, empezó en 0 terminó en 4.
#
#
# También es posible empezar la función `range()` en un valor diferente, o especificar un incremento diferente (incluso números negativps; algunas veces a esto se le llama el `step`):

# %%
for i in range(5, 10):
  print(i)

# %%
for i in range(0, 10, 3):
  print(i)

# %%
for i in range(-10, -100, -30):
  print(i)

# %% [markdown]
# Para iterar sobre los índices de una sucesión, podemos combinar `range( )` y `len( )` como sigue:

# %%
a = ['Hola', 'a', 'Todo', 'el', 'Mundo']
for i in range(len(a)):
  print(i, a[i])
